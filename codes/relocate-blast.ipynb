# %%
import pygmt
import numpy as np
import pandas as pd
region = [-10.5, -5, 51.5, 55.5]
seisblast_files = '/home/bmelo/bin/SeisBlast/files'
seisblast_codes = '/home/bmelo/bin/SeisBlast/codes'

# %% [markdown]
# **Function to prepare and select the blast catalogue data per quarry**

# %%
def quarry_select(quarry_locations_df, blast_catalogue_df, radius):
    """
    Relocate blasts using GMT select based on quarry locations and a specified radius.
    Parameters:
    quarry_locations_df (pd.DataFrame): DataFrame containing quarry locations with columns 'lat' and 'lon'.
    blast_catalogue_df (pd.DataFrame): DataFrame containing blast events with columns 'LON(deg)', 'LAT(deg)', and 'EVENT-ID'.
    radius (str): Radius for selection in GMT format (e.g., '10k' for 10 kilometers).
    Returns:
    tuple: A tuple containing:
        - relocated_blasts (pd.DataFrame): DataFrame of relocated blasts with columns 'lon_ev', 'lat_ev', 'id-ev', 'lon-quarry', 'lat-quarry'.
        - remain_blasts (pd.DataFrame): DataFrame of remaining blasts that were not relocated.
        - repeated_blasts (pd.DataFrame): DataFrame of blasts that were assigned to more than one quarry location.
    """

    relocated_blasts = pd.DataFrame()
    repeated_blasts = pd.DataFrame()
    result = pd.DataFrame()
    
    #convert the blast catalogue dataframe to lon, lat (ASCII) to load into gmt select
    blast_catalogue_df.to_csv(f'{seisblast_files}/Eire_blasts.gmt', 
            columns=['LON(deg)','LAT(deg)','EVENT-ID'], 
            sep="\t", 
            header=False, 
            index=False)

    for index, row in quarry_locations_df.iterrows():
        quarry_lat = quarry_locations_df.loc[index, "lat"]
        quarry_lon = quarry_locations_df.loc[index, "lon"]
        quarry_loc = str(quarry_lon) + "/" + str(quarry_lat)

        result = pygmt.select(
            data=f'{seisblast_files}/Eire_blasts.gmt',
            output_type="pandas",
            dist2pt=quarry_loc + "+d" + radius,
            region=region,
        )

        if not result.empty:
            result["new-lon"] = quarry_lon
            result["new-lat"] = quarry_lat
            relocated_blasts = pd.concat([relocated_blasts, result], ignore_index=True)

    if not relocated_blasts.empty:
        relocated_blasts.columns = [
            "lon_ev",
            "lat_ev",
            "id-ev",
            "lon-quarry",
            "lat-quarry",
        ]
    
        # Filter values that appear more than once
        value_counts = relocated_blasts['id-ev'].value_counts()
        repeated_values = value_counts[value_counts > 1]
        
        # Check if there are no repeated values
        if not repeated_values.any():
            print('    ~~~the selection radius '+str(radius)+' found ' +str(relocated_blasts.shape[0])+' matches and no double assigments.')
        else: 
            # If there are repeated values, print the number of non-unique assignments
            print('    ~~~the selection radius '+str(radius)+' found ' +str(relocated_blasts.shape[0])+' matches and '+str(repeated_values.iloc[0].max())+' non-unique assigments.')
            repeated_blasts = relocated_blasts[relocated_blasts['id-ev'].isin(repeated_values.index)]
            relocated_blasts = relocated_blasts[~relocated_blasts['id-ev'].isin(repeated_values.index)]
        
        # Build new event list with the remaining blasts
        remain_blasts = blast_catalogue_df[~blast_catalogue_df['EVENT-ID'].isin(relocated_blasts["id-ev"])]
        print("    ~~~out of "+str(blast_catalogue_df.shape[0])+" initial events, "+str(remain_blasts.shape[0])+" quarry blast events remain")
    else:
        # If no matches were found
        print('    ~~~the selection radius '+str(radius)+' found no matches.')
        
    return relocated_blasts, remain_blasts, repeated_blasts

# %% [markdown]
# **Load station,  quarry data**

# %%
# Load station data to lon lat file and dataframe
stations_head = ['sta', 'name','lat', 'lon', 'elevation', 'net', 'end']
stations = pd.read_csv(
    "/mnt/store/senad/repos/for_bruna/QUARRY_BLASTS/ADMIN/Ireland_Britain_Stations", 
    delimiter=' ',
    names=stations_head)

quarries = pd.read_csv(
    '/home/bmelo/bin/Quarry/quarry_new_update1.gmt',
    header=0, 
    sep=r'\s+',
    names=['lon','lat'])
quarries['z']=1

# %% [markdown]
# **Loop from smaller radius search to a maximum of ~8km and save results to files**

# %%
#kind of empirically tested radius values to select the quarry blasts without double assigments
#by double assigments we mean that the same blast is assigned to more than one quarry
#from 0.5 to 8 km search in ~100m steps
radius = np.concatenate((np.linspace(0.005, 0.0095, int((0.0095 - 0.005) / 0.0005) + 1), 
						 np.linspace(0.01, 0.08, int((0.08 - 0.01) / 0.001) + 1)))

# Initialize relocated_blasts_all
relocated_blasts_all = pd.DataFrame()
doubles_all = pd.DataFrame()
blasts_catalogue = pd.read_csv(r'/mnt/REPO/QUARRY-BLASTS/CATALOGS/quarry-blast-catalog-2013-2014.csv', 
                     sep=r'\s+')

remain_blasts_catalogue = blasts_catalogue
for r in radius:
    print(" ")
    print(" >>processing radius "+str(r))
    quarry_blasts, remain_blasts_catalogue, doubles = quarry_select(quarries, remain_blasts_catalogue, str(r))
    relocated_blasts_all = pd.concat([relocated_blasts_all, quarry_blasts], ignore_index=True)
    doubles_all = pd.concat([doubles_all, doubles], ignore_index=True)
    
relocated_blasts_all.to_csv(f'{seisblast_files}/Eire_blasts_relocated.csv', index=False)

unique_id_ev_count = doubles_all['id-ev'].nunique()
print(f" >>number of doubles': {unique_id_ev_count}")
doubles_filter = doubles_all.drop_duplicates().sort_values(by='id-ev')
doubles_filter.to_csv(f'{seisblast_files}/Eire_blasts_toreview.csv', index=False)
# Out:
#
#  >>processing radius 0.005
#     ~~~the selection radius 0.005 found 93 matches and no double assigments.
#     ~~~out of 1411 initial events, 1318 quarry blast events remain
#
#  >>processing radius 0.0055
#     ~~~the selection radius 0.0055 found 22 matches and no double assigments.
#     ~~~out of 1318 initial events, 1296 quarry blast events remain
#
#  >>processing radius 0.006
#     ~~~the selection radius 0.006 found 22 matches and no double assigments.
#     ~~~out of 1296 initial events, 1274 quarry blast events remain
#
#  >>processing radius 0.006500000000000001
#     ~~~the selection radius 0.006500000000000001 found 12 matches and no double assigments.
#     ~~~out of 1274 initial events, 1262 quarry blast events remain
#
#  >>processing radius 0.007
#     ~~~the selection radius 0.007 found 20 matches and no double assigments.
#     ~~~out of 1262 initial events, 1242 quarry blast events remain
#
#  >>processing radius 0.0075
#     ~~~the selection radius 0.0075 found 28 matches and no double assigments.
#     ~~~out of 1242 initial events, 1214 quarry blast events remain
#
#  >>processing radius 0.008
#     ~~~the selection radius 0.008 found 15 matches and no double assigments.
#     ~~~out of 1214 initial events, 1199 quarry blast events remain
#
#  >>processing radius 0.0085
#     ~~~the selection radius 0.0085 found 30 matches and no double assigments.
#     ~~~out of 1199 initial events, 1169 quarry blast events remain
#
#  >>processing radius 0.009000000000000001
#     ~~~the selection radius 0.009000000000000001 found 23 matches and no double assigments.
#     ~~~out of 1169 initial events, 1146 quarry blast events remain
#
#  >>processing radius 0.0095
#     ~~~the selection radius 0.0095 found 20 matches and no double assigments.
#     ~~~out of 1146 initial events, 1126 quarry blast events remain
#
#  >>processing radius 0.01
#     ~~~the selection radius 0.01 found 28 matches and no double assigments.
#     ~~~out of 1126 initial events, 1098 quarry blast events remain
#
#  >>processing radius 0.011
#     ~~~the selection radius 0.011 found 52 matches and 2 non-unique assigments.
#     ~~~out of 1098 initial events, 1048 quarry blast events remain
#
#  >>processing radius 0.012
#     ~~~the selection radius 0.012 found 51 matches and 2 non-unique assigments.
#     ~~~out of 1048 initial events, 1003 quarry blast events remain
#
#  >>processing radius 0.013000000000000001
#     ~~~the selection radius 0.013000000000000001 found 68 matches and 2 non-unique assigments.
#     ~~~out of 1003 initial events, 941 quarry blast events remain
#
#  >>processing radius 0.014
#     ~~~the selection radius 0.014 found 62 matches and 2 non-unique assigments.
#     ~~~out of 941 initial events, 887 quarry blast events remain
#
#  >>processing radius 0.015
#     ~~~the selection radius 0.015 found 64 matches and 2 non-unique assigments.
#     ~~~out of 887 initial events, 831 quarry blast events remain
#
#  >>processing radius 0.016
#     ~~~the selection radius 0.016 found 57 matches and 2 non-unique assigments.
#     ~~~out of 831 initial events, 782 quarry blast events remain
#
#  >>processing radius 0.017
#     ~~~the selection radius 0.017 found 60 matches and 2 non-unique assigments.
#     ~~~out of 782 initial events, 730 quarry blast events remain
#
#  >>processing radius 0.018000000000000002
#     ~~~the selection radius 0.018000000000000002 found 66 matches and 2 non-unique assigments.
#     ~~~out of 730 initial events, 674 quarry blast events remain
#
#  >>processing radius 0.019000000000000003
#     ~~~the selection radius 0.019000000000000003 found 44 matches and 2 non-unique assigments.
#     ~~~out of 674 initial events, 640 quarry blast events remain
#
#  >>processing radius 0.02
#     ~~~the selection radius 0.02 found 62 matches and 2 non-unique assigments.
#     ~~~out of 640 initial events, 590 quarry blast events remain
#
#  >>processing radius 0.020999999999999998
#     ~~~the selection radius 0.020999999999999998 found 56 matches and 2 non-unique assigments.
#     ~~~out of 590 initial events, 546 quarry blast events remain
#
#  >>processing radius 0.022
#     ~~~the selection radius 0.022 found 49 matches and 2 non-unique assigments.
#     ~~~out of 546 initial events, 509 quarry blast events remain
#
#  >>processing radius 0.023
#     ~~~the selection radius 0.023 found 61 matches and 2 non-unique assigments.
#     ~~~out of 509 initial events, 464 quarry blast events remain
#
#  >>processing radius 0.024
#     ~~~the selection radius 0.024 found 54 matches and 2 non-unique assigments.
#     ~~~out of 464 initial events, 426 quarry blast events remain
#
#  >>processing radius 0.025
#     ~~~the selection radius 0.025 found 68 matches and 2 non-unique assigments.
#     ~~~out of 426 initial events, 378 quarry blast events remain
#
#  >>processing radius 0.026000000000000002
#     ~~~the selection radius 0.026000000000000002 found 56 matches and 2 non-unique assigments.
#     ~~~out of 378 initial events, 344 quarry blast events remain
#
#  >>processing radius 0.027000000000000003
#     ~~~the selection radius 0.027000000000000003 found 52 matches and 2 non-unique assigments.
#     ~~~out of 344 initial events, 314 quarry blast events remain
#
#  >>processing radius 0.028000000000000004
#     ~~~the selection radius 0.028000000000000004 found 50 matches and 2 non-unique assigments.
#     ~~~out of 314 initial events, 288 quarry blast events remain
#
#  >>processing radius 0.028999999999999998
#     ~~~the selection radius 0.028999999999999998 found 55 matches and 2 non-unique assigments.
#     ~~~out of 288 initial events, 257 quarry blast events remain
#
#  >>processing radius 0.03
#     ~~~the selection radius 0.03 found 48 matches and 2 non-unique assigments.
#     ~~~out of 257 initial events, 233 quarry blast events remain
#
#  >>processing radius 0.031
#     ~~~the selection radius 0.031 found 42 matches and 2 non-unique assigments.
#     ~~~out of 233 initial events, 215 quarry blast events remain
#
#  >>processing radius 0.032
#     ~~~the selection radius 0.032 found 50 matches and 2 non-unique assigments.
#     ~~~out of 215 initial events, 189 quarry blast events remain
#
#  >>processing radius 0.033
#     ~~~the selection radius 0.033 found 46 matches and 2 non-unique assigments.
#     ~~~out of 189 initial events, 169 quarry blast events remain
#
#  >>processing radius 0.034
#     ~~~the selection radius 0.034 found 47 matches and 2 non-unique assigments.
#     ~~~out of 169 initial events, 148 quarry blast events remain
#
#  >>processing radius 0.035
#     ~~~the selection radius 0.035 found 41 matches and 2 non-unique assigments.
#     ~~~out of 148 initial events, 133 quarry blast events remain
#
#  >>processing radius 0.036000000000000004
#     ~~~the selection radius 0.036000000000000004 found 37 matches and 2 non-unique assigments.
#     ~~~out of 133 initial events, 122 quarry blast events remain
#
#  >>processing radius 0.037
#     ~~~the selection radius 0.037 found 33 matches and 2 non-unique assigments.
#     ~~~out of 122 initial events, 115 quarry blast events remain
#
#  >>processing radius 0.038
#     ~~~the selection radius 0.038 found 30 matches and 2 non-unique assigments.
#     ~~~out of 115 initial events, 111 quarry blast events remain
#
#  >>processing radius 0.039
#     ~~~the selection radius 0.039 found 36 matches and 2 non-unique assigments.
#     ~~~out of 111 initial events, 101 quarry blast events remain
#
#  >>processing radius 0.04
#     ~~~the selection radius 0.04 found 31 matches and 2 non-unique assigments.
#     ~~~out of 101 initial events, 96 quarry blast events remain
#
#  >>processing radius 0.041
#     ~~~the selection radius 0.041 found 33 matches and 2 non-unique assigments.
#     ~~~out of 96 initial events, 89 quarry blast events remain
#
#  >>processing radius 0.042
#     ~~~the selection radius 0.042 found 32 matches and 2 non-unique assigments.
#     ~~~out of 89 initial events, 83 quarry blast events remain
#
#  >>processing radius 0.043000000000000003
#     ~~~the selection radius 0.043000000000000003 found 30 matches and 2 non-unique assigments.
#     ~~~out of 83 initial events, 79 quarry blast events remain
#
#  >>processing radius 0.044000000000000004
#     ~~~the selection radius 0.044000000000000004 found 32 matches and 2 non-unique assigments.
#     ~~~out of 79 initial events, 73 quarry blast events remain
#
#  >>processing radius 0.045000000000000005
#     ~~~the selection radius 0.045000000000000005 found 33 matches and 2 non-unique assigments.
#     ~~~out of 73 initial events, 66 quarry blast events remain
#
#  >>processing radius 0.046000000000000006
#     ~~~the selection radius 0.046000000000000006 found 35 matches and 2 non-unique assigments.
#     ~~~out of 66 initial events, 57 quarry blast events remain
#
#  >>processing radius 0.047
#     ~~~the selection radius 0.047 found 30 matches and 2 non-unique assigments.
#     ~~~out of 57 initial events, 53 quarry blast events remain
#
#  >>processing radius 0.048
#     ~~~the selection radius 0.048 found 29 matches and 2 non-unique assigments.
#     ~~~out of 53 initial events, 50 quarry blast events remain
#
#  >>processing radius 0.049
#     ~~~the selection radius 0.049 found 30 matches and 3 non-unique assigments.
#     ~~~out of 50 initial events, 47 quarry blast events remain
#
#  >>processing radius 0.05
#     ~~~the selection radius 0.05 found 33 matches and 3 non-unique assigments.
#     ~~~out of 47 initial events, 43 quarry blast events remain
#
#  >>processing radius 0.051000000000000004
#     ~~~the selection radius 0.051000000000000004 found 33 matches and 3 non-unique assigments.
#     ~~~out of 43 initial events, 39 quarry blast events remain
#
#  >>processing radius 0.052000000000000005
#     ~~~the selection radius 0.052000000000000005 found 30 matches and 3 non-unique assigments.
#     ~~~out of 39 initial events, 38 quarry blast events remain
#
#  >>processing radius 0.053000000000000005
#     ~~~the selection radius 0.053000000000000005 found 30 matches and 3 non-unique assigments.
#     ~~~out of 38 initial events, 37 quarry blast events remain
#
#  >>processing radius 0.054
#     ~~~the selection radius 0.054 found 30 matches and 3 non-unique assigments.
#     ~~~out of 37 initial events, 36 quarry blast events remain
#
#  >>processing radius 0.055
#     ~~~the selection radius 0.055 found 30 matches and 3 non-unique assigments.
#     ~~~out of 36 initial events, 35 quarry blast events remain
#
#  >>processing radius 0.056
#     ~~~the selection radius 0.056 found 30 matches and 3 non-unique assigments.
#     ~~~out of 35 initial events, 34 quarry blast events remain
#
#  >>processing radius 0.057
#     ~~~the selection radius 0.057 found 29 matches and 3 non-unique assigments.
#     ~~~out of 34 initial events, 34 quarry blast events remain
#
#  >>processing radius 0.058
#     ~~~the selection radius 0.058 found 30 matches and 3 non-unique assigments.
#     ~~~out of 34 initial events, 33 quarry blast events remain
#
#  >>processing radius 0.059000000000000004
#     ~~~the selection radius 0.059000000000000004 found 29 matches and 3 non-unique assigments.
#     ~~~out of 33 initial events, 33 quarry blast events remain
#
#  >>processing radius 0.060000000000000005
#     ~~~the selection radius 0.060000000000000005 found 30 matches and 3 non-unique assigments.
#     ~~~out of 33 initial events, 32 quarry blast events remain
#
#  >>processing radius 0.061000000000000006
#     ~~~the selection radius 0.061000000000000006 found 31 matches and 3 non-unique assigments.
#     ~~~out of 32 initial events, 30 quarry blast events remain
#
#  >>processing radius 0.062000000000000006
#     ~~~the selection radius 0.062000000000000006 found 29 matches and 3 non-unique assigments.
#     ~~~out of 30 initial events, 30 quarry blast events remain
#
#  >>processing radius 0.063
#     ~~~the selection radius 0.063 found 29 matches and 3 non-unique assigments.
#     ~~~out of 30 initial events, 30 quarry blast events remain
#
#  >>processing radius 0.064
#     ~~~the selection radius 0.064 found 31 matches and 3 non-unique assigments.
#     ~~~out of 30 initial events, 29 quarry blast events remain
#
#  >>processing radius 0.065
#     ~~~the selection radius 0.065 found 31 matches and 3 non-unique assigments.
#     ~~~out of 29 initial events, 29 quarry blast events remain
#
#  >>processing radius 0.066
#     ~~~the selection radius 0.066 found 33 matches and 4 non-unique assigments.
#     ~~~out of 29 initial events, 28 quarry blast events remain
#
#  >>processing radius 0.067
#     ~~~the selection radius 0.067 found 32 matches and 4 non-unique assigments.
#     ~~~out of 28 initial events, 28 quarry blast events remain
#
#  >>processing radius 0.068
#     ~~~the selection radius 0.068 found 32 matches and 4 non-unique assigments.
#     ~~~out of 28 initial events, 28 quarry blast events remain
#
#  >>processing radius 0.069
#     ~~~the selection radius 0.069 found 32 matches and 4 non-unique assigments.
#     ~~~out of 28 initial events, 28 quarry blast events remain
#
#  >>processing radius 0.06999999999999999
#     ~~~the selection radius 0.06999999999999999 found 32 matches and 4 non-unique assigments.
#     ~~~out of 28 initial events, 28 quarry blast events remain
#
#  >>processing radius 0.071
#     ~~~the selection radius 0.071 found 32 matches and 4 non-unique assigments.
#     ~~~out of 28 initial events, 28 quarry blast events remain
#
#  >>processing radius 0.072
#     ~~~the selection radius 0.072 found 32 matches and 4 non-unique assigments.
#     ~~~out of 28 initial events, 28 quarry blast events remain
#
#  >>processing radius 0.073
#     ~~~the selection radius 0.073 found 32 matches and 4 non-unique assigments.
#     ~~~out of 28 initial events, 28 quarry blast events remain
#
#  >>processing radius 0.074
#     ~~~the selection radius 0.074 found 32 matches and 4 non-unique assigments.
#     ~~~out of 28 initial events, 28 quarry blast events remain
#
#  >>processing radius 0.075
#     ~~~the selection radius 0.075 found 34 matches and 4 non-unique assigments.
#     ~~~out of 28 initial events, 27 quarry blast events remain
#
#  >>processing radius 0.076
#     ~~~the selection radius 0.076 found 33 matches and 4 non-unique assigments.
#     ~~~out of 27 initial events, 27 quarry blast events remain
#
#  >>processing radius 0.077
#     ~~~the selection radius 0.077 found 33 matches and 4 non-unique assigments.
#     ~~~out of 27 initial events, 27 quarry blast events remain
#
#  >>processing radius 0.078
#     ~~~the selection radius 0.078 found 34 matches and 4 non-unique assigments.
#     ~~~out of 27 initial events, 27 quarry blast events remain
#
#  >>processing radius 0.079
#     ~~~the selection radius 0.079 found 36 matches and 5 non-unique assigments.
#     ~~~out of 27 initial events, 26 quarry blast events remain
#
#  >>processing radius 0.08
#     ~~~the selection radius 0.08 found 35 matches and 5 non-unique assigments.
#     ~~~out of 26 initial events, 26 quarry blast events remain
#  >>number of doubles': 14

# %% [markdown]
# **Plot results with PyGMT**

# %%
fig = pygmt.Figure()
fig.basemap(region=region, projection="M10c", frame="a1")
fig.coast(shorelines=True, water="skyblue", land="lightgray")
#Plot quarry mine locations as black circles
fig.plot(
    x=quarries["lon"],
    y=quarries["lat"],
    style="s0.3c",
    fill="black",
    pen="black",
    label="Quarry"
)
#Plot relocated blasts as red circles
fig.plot(x=relocated_blasts_all["lon-quarry"],
         y=relocated_blasts_all["lat-quarry"],
         style="t0.2c",
         fill="green",
         pen="black",
         label="Relocated Blasts")
#Plot remaining blasts as yellow circles
fig.plot(
    x=remain_blasts_catalogue['LON(deg)'],
    y=remain_blasts_catalogue['LAT(deg)'],
    style="t0.2c",
    fill="yellow",
    pen="black",
    label="Lost Blasts"
)
#Plot remaining blasts as yellow circles
fig.plot(
    x=doubles_all['lon_ev'],
    y=doubles_all['lat_ev'],
    style="t0.2c",
    fill="red",
    pen="black",
    label="Review Blasts"
)
fig.legend(position="jTL")
fig.show()
