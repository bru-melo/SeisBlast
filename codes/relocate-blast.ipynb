# %%
import pygmt
import numpy as np
import pandas as pd
region = [-10.5, -5, 51.5, 55.5]
seisblast_files = '/home/bmelo/bin/SeisBlast/files'
seisblast_codes = '/home/bmelo/bin/SeisBlast/codes'

# %% [markdown]
# **Function to prepare and select the blast catalogue data per quarry**

# %%
def quarry_select(quarry_locations_df, blast_catalogue_df, radius):
    """
    Relocate blasts using GMT select based on quarry locations and a specified radius.
    Parameters:
    quarry_locations_df (pd.DataFrame): DataFrame containing quarry locations with columns 'lat' and 'lon'.
    blast_catalogue_df (pd.DataFrame): DataFrame containing blast events with columns 'LON(deg)', 'LAT(deg)', and 'EVENT-ID'.
    radius (str): Radius for selection in GMT format (e.g., '10k' for 10 kilometers).
    Returns:
    tuple: A tuple containing:
        - relocated_blasts (pd.DataFrame): DataFrame of relocated blasts with columns 'lon_ev', 'lat_ev', 'id-ev', 'lon-quarry', 'lat-quarry'.
        - remain_blasts (pd.DataFrame): DataFrame of remaining blasts that were not relocated.
        - repeated_blasts (pd.DataFrame): DataFrame of blasts that were assigned to more than one quarry location.
    """

    relocated_blasts = pd.DataFrame()
    repeated_blasts = pd.DataFrame()
    result = pd.DataFrame()
    
    #convert the blast catalogue dataframe to lon, lat (ASCII) to load into gmt select
    blast_catalogue_df.to_csv(f'{seisblast_files}/Eire_blasts.gmt', 
            columns=['LON(deg)','LAT(deg)','EVENT-ID'], 
            sep="\t", 
            header=False, 
            index=False)

    for index, row in quarry_locations_df.iterrows():
        quarry_lat = quarry_locations_df.loc[index, "lat"]
        quarry_lon = quarry_locations_df.loc[index, "lon"]
        quarry_loc = str(quarry_lon) + "/" + str(quarry_lat)

        result = pygmt.select(
            data=f'{seisblast_files}/Eire_blasts.gmt',
            output_type="pandas",
            dist2pt=quarry_loc + "+d" + radius,
            region=region,
        )

        if not result.empty:
            result["new-lon"] = quarry_lon
            result["new-lat"] = quarry_lat
            relocated_blasts = pd.concat([relocated_blasts, result], ignore_index=True)

    if not relocated_blasts.empty:
        relocated_blasts.columns = [
            "lon_ev",
            "lat_ev",
            "id-ev",
            "lon-quarry",
            "lat-quarry",
        ]
    
        # Filter values that appear more than once
        value_counts = relocated_blasts['id-ev'].value_counts()
        repeated_values = value_counts[value_counts > 1]
        
        # Check if there are no repeated values
        if not repeated_values.any():
            print('    ~~~the selection radius '+str(radius)+' found ' +str(relocated_blasts.shape[0])+' matches and no double assigments.')
        else: 
            # If there are repeated values, print the number of non-unique assignments
            print('    ~~~the selection radius '+str(radius)+' found ' +str(relocated_blasts.shape[0])+' matches and '+str(repeated_values.iloc[0].max())+' non-unique assigments.')
            repeated_blasts = relocated_blasts[relocated_blasts['id-ev'].isin(repeated_values.index)]
            relocated_blasts = relocated_blasts[~relocated_blasts['id-ev'].isin(repeated_values.index)]
        
        # Build new event list with the remaining blasts
        remain_blasts = blast_catalogue_df[~blast_catalogue_df['EVENT-ID'].isin(relocated_blasts["id-ev"])]
        print("    ~~~out of "+str(blast_catalogue_df.shape[0])+" initial events, "+str(remain_blasts.shape[0])+" quarry blast events remain")
    else:
        # If no matches were found
        print('    ~~~the selection radius '+str(radius)+' found no matches.')
        
    return relocated_blasts, remain_blasts, repeated_blasts

# %% [markdown]
# **Load station,  quarry data**

# %%
# Load station data to lon lat file and dataframe
stations_head = ['sta', 'name','lat', 'lon', 'elevation', 'net', 'end']
stations = pd.read_csv(
    "/mnt/store/senad/repos/for_bruna/QUARRY_BLASTS/ADMIN/Ireland_Britain_Stations", 
    delimiter=' ',
    names=stations_head)

# quarries = pd.read_csv(
#     '/home/bmelo/bin/Quarry/quarry_new_update1.gmt',
#     header=0, 
#     sep=r'\s+',
#     names=['lon','lat'])
quarries = pd.read_csv('/home/bmelo/bin/Quarry/James_files/IRELAND.quarry.coords.txt',
                       sep = r'\s+',
                       header=None,
                       names=['name','co','lat','lon'])
quarries['z']=1

# %% [markdown]
# **Loop from smaller radius search to a maximum of ~8km and save results to files**

# %%
#kind of empirically tested radius values to select the quarry blasts without double assigments
#by double assigments we mean that the same blast is assigned to more than one quarry
#from 0.5 to 8 km search in ~100m steps
radius = np.concatenate((np.linspace(0.005, 0.0095, int((0.0095 - 0.005) / 0.0005) + 1), 
						 np.linspace(0.01, 0.08, int((0.08 - 0.01) / 0.001) + 1)))

# Initialize relocated_blasts_all
relocated_blasts_all = pd.DataFrame()
doubles_all = pd.DataFrame()
blasts_catalogue = pd.read_csv(r'/mnt/REPO/QUARRY-BLASTS/CATALOGS/quarry-blast-catalog-2013-2014.csv', 
                     sep=r'\s+')

remain_blasts_catalogue = blasts_catalogue

for r in radius:
    print(" ")
    print(" >>processing radius "+str(r))
    quarry_blasts, remain_blasts_catalogue, doubles = quarry_select(quarries, remain_blasts_catalogue, str(r))
    relocated_blasts_all = pd.concat([relocated_blasts_all, quarry_blasts], ignore_index=True)
    doubles_all = pd.concat([doubles_all, doubles], ignore_index=True)
    
relocated_blasts_all.to_csv(f'{seisblast_files}/Eire_blasts_relocated.csv', index=False)

unique_id_ev_count = doubles_all['id-ev'].nunique()
print(f" >>number of doubles': {unique_id_ev_count}")
doubles_filter = doubles_all.drop_duplicates().sort_values(by='id-ev')
doubles_filter.to_csv(f'{seisblast_files}/Eire_blasts_toreview.csv', index=False)
# Out:
#
#  >>processing radius 0.005
#     ~~~the selection radius 0.005 found 91 matches and no double assigments.
#     ~~~out of 1411 initial events, 1320 quarry blast events remain
#
#  >>processing radius 0.0055
#     ~~~the selection radius 0.0055 found 23 matches and no double assigments.
#     ~~~out of 1320 initial events, 1297 quarry blast events remain
#
#  >>processing radius 0.006
#     ~~~the selection radius 0.006 found 23 matches and no double assigments.
#     ~~~out of 1297 initial events, 1274 quarry blast events remain
#
#  >>processing radius 0.006500000000000001
#     ~~~the selection radius 0.006500000000000001 found 14 matches and no double assigments.
#     ~~~out of 1274 initial events, 1260 quarry blast events remain
#
#  >>processing radius 0.007
#     ~~~the selection radius 0.007 found 22 matches and 2 non-unique assigments.
#     ~~~out of 1260 initial events, 1240 quarry blast events remain
#
#  >>processing radius 0.0075
#     ~~~the selection radius 0.0075 found 28 matches and 2 non-unique assigments.
#     ~~~out of 1240 initial events, 1216 quarry blast events remain
#
#  >>processing radius 0.008
#     ~~~the selection radius 0.008 found 18 matches and 2 non-unique assigments.
#     ~~~out of 1216 initial events, 1202 quarry blast events remain
#
#  >>processing radius 0.0085
#     ~~~the selection radius 0.0085 found 37 matches and 2 non-unique assigments.
#     ~~~out of 1202 initial events, 1171 quarry blast events remain
#
#  >>processing radius 0.009000000000000001
#     ~~~the selection radius 0.009000000000000001 found 27 matches and 2 non-unique assigments.
#     ~~~out of 1171 initial events, 1150 quarry blast events remain
#
#  >>processing radius 0.0095
#     ~~~the selection radius 0.0095 found 30 matches and 2 non-unique assigments.
#     ~~~out of 1150 initial events, 1126 quarry blast events remain
#
#  >>processing radius 0.01
#     ~~~the selection radius 0.01 found 34 matches and 2 non-unique assigments.
#     ~~~out of 1126 initial events, 1098 quarry blast events remain
#
#  >>processing radius 0.011
#     ~~~the selection radius 0.011 found 59 matches and 2 non-unique assigments.
#     ~~~out of 1098 initial events, 1047 quarry blast events remain
#
#  >>processing radius 0.012
#     ~~~the selection radius 0.012 found 62 matches and 2 non-unique assigments.
#     ~~~out of 1047 initial events, 997 quarry blast events remain
#
#  >>processing radius 0.013000000000000001
#     ~~~the selection radius 0.013000000000000001 found 82 matches and 2 non-unique assigments.
#     ~~~out of 997 initial events, 929 quarry blast events remain
#
#  >>processing radius 0.014
#     ~~~the selection radius 0.014 found 76 matches and 2 non-unique assigments.
#     ~~~out of 929 initial events, 869 quarry blast events remain
#
#  >>processing radius 0.015
#     ~~~the selection radius 0.015 found 74 matches and 2 non-unique assigments.
#     ~~~out of 869 initial events, 811 quarry blast events remain
#
#  >>processing radius 0.016
#     ~~~the selection radius 0.016 found 62 matches and 2 non-unique assigments.
#     ~~~out of 811 initial events, 765 quarry blast events remain
#
#  >>processing radius 0.017
#     ~~~the selection radius 0.017 found 81 matches and 2 non-unique assigments.
#     ~~~out of 765 initial events, 702 quarry blast events remain
#
#  >>processing radius 0.018000000000000002
#     ~~~the selection radius 0.018000000000000002 found 79 matches and 2 non-unique assigments.
#     ~~~out of 702 initial events, 643 quarry blast events remain
#
#  >>processing radius 0.019000000000000003
#     ~~~the selection radius 0.019000000000000003 found 59 matches and 2 non-unique assigments.
#     ~~~out of 643 initial events, 604 quarry blast events remain
#
#  >>processing radius 0.02
#     ~~~the selection radius 0.02 found 79 matches and 2 non-unique assigments.
#     ~~~out of 604 initial events, 549 quarry blast events remain
#
#  >>processing radius 0.020999999999999998
#     ~~~the selection radius 0.020999999999999998 found 74 matches and 2 non-unique assigments.
#     ~~~out of 549 initial events, 499 quarry blast events remain
#
#  >>processing radius 0.022
#     ~~~the selection radius 0.022 found 62 matches and 2 non-unique assigments.
#     ~~~out of 499 initial events, 461 quarry blast events remain
#
#  >>processing radius 0.023
#     ~~~the selection radius 0.023 found 76 matches and 2 non-unique assigments.
#     ~~~out of 461 initial events, 413 quarry blast events remain
#
#  >>processing radius 0.024
#     ~~~the selection radius 0.024 found 64 matches and 2 non-unique assigments.
#     ~~~out of 413 initial events, 377 quarry blast events remain
#
#  >>processing radius 0.025
#     ~~~the selection radius 0.025 found 84 matches and 2 non-unique assigments.
#     ~~~out of 377 initial events, 327 quarry blast events remain
#
#  >>processing radius 0.026000000000000002
#     ~~~the selection radius 0.026000000000000002 found 69 matches and 2 non-unique assigments.
#     ~~~out of 327 initial events, 298 quarry blast events remain
#
#  >>processing radius 0.027000000000000003
#     ~~~the selection radius 0.027000000000000003 found 78 matches and 2 non-unique assigments.
#     ~~~out of 298 initial events, 260 quarry blast events remain
#
#  >>processing radius 0.028000000000000004
#     ~~~the selection radius 0.028000000000000004 found 70 matches and 3 non-unique assigments.
#     ~~~out of 260 initial events, 233 quarry blast events remain
#
#  >>processing radius 0.028999999999999998
#     ~~~the selection radius 0.028999999999999998 found 77 matches and 3 non-unique assigments.
#     ~~~out of 233 initial events, 201 quarry blast events remain
#
#  >>processing radius 0.03
#     ~~~the selection radius 0.03 found 69 matches and 3 non-unique assigments.
#     ~~~out of 201 initial events, 177 quarry blast events remain
#
#  >>processing radius 0.031
#     ~~~the selection radius 0.031 found 61 matches and 3 non-unique assigments.
#     ~~~out of 177 initial events, 161 quarry blast events remain
#
#  >>processing radius 0.032
#     ~~~the selection radius 0.032 found 65 matches and 3 non-unique assigments.
#     ~~~out of 161 initial events, 142 quarry blast events remain
#
#  >>processing radius 0.033
#     ~~~the selection radius 0.033 found 67 matches and 3 non-unique assigments.
#     ~~~out of 142 initial events, 121 quarry blast events remain
#
#  >>processing radius 0.034
#     ~~~the selection radius 0.034 found 64 matches and 3 non-unique assigments.
#     ~~~out of 121 initial events, 103 quarry blast events remain
#
#  >>processing radius 0.035
#     ~~~the selection radius 0.035 found 58 matches and 3 non-unique assigments.
#     ~~~out of 103 initial events, 91 quarry blast events remain
#
#  >>processing radius 0.036000000000000004
#     ~~~the selection radius 0.036000000000000004 found 53 matches and 3 non-unique assigments.
#     ~~~out of 91 initial events, 84 quarry blast events remain
#
#  >>processing radius 0.037
#     ~~~the selection radius 0.037 found 53 matches and 3 non-unique assigments.
#     ~~~out of 84 initial events, 77 quarry blast events remain
#
#  >>processing radius 0.038
#     ~~~the selection radius 0.038 found 53 matches and 3 non-unique assigments.
#     ~~~out of 77 initial events, 73 quarry blast events remain
#
#  >>processing radius 0.039
#     ~~~the selection radius 0.039 found 57 matches and 3 non-unique assigments.
#     ~~~out of 73 initial events, 65 quarry blast events remain
#
#  >>processing radius 0.04
#     ~~~the selection radius 0.04 found 54 matches and 3 non-unique assigments.
#     ~~~out of 65 initial events, 60 quarry blast events remain
#
#  >>processing radius 0.041
#     ~~~the selection radius 0.041 found 54 matches and 3 non-unique assigments.
#     ~~~out of 60 initial events, 55 quarry blast events remain
#
#  >>processing radius 0.042
#     ~~~the selection radius 0.042 found 52 matches and 3 non-unique assigments.
#     ~~~out of 55 initial events, 52 quarry blast events remain
#
#  >>processing radius 0.043000000000000003
#     ~~~the selection radius 0.043000000000000003 found 51 matches and 3 non-unique assigments.
#     ~~~out of 52 initial events, 50 quarry blast events remain
#
#  >>processing radius 0.044000000000000004
#     ~~~the selection radius 0.044000000000000004 found 51 matches and 3 non-unique assigments.
#     ~~~out of 50 initial events, 49 quarry blast events remain
#
#  >>processing radius 0.045000000000000005
#     ~~~the selection radius 0.045000000000000005 found 58 matches and 3 non-unique assigments.
#     ~~~out of 49 initial events, 42 quarry blast events remain
#
#  >>processing radius 0.046000000000000006
#     ~~~the selection radius 0.046000000000000006 found 55 matches and 3 non-unique assigments.
#     ~~~out of 42 initial events, 38 quarry blast events remain
#
#  >>processing radius 0.047
#     ~~~the selection radius 0.047 found 53 matches and 3 non-unique assigments.
#     ~~~out of 38 initial events, 37 quarry blast events remain
#
#  >>processing radius 0.048
#     ~~~the selection radius 0.048 found 55 matches and 4 non-unique assigments.
#     ~~~out of 37 initial events, 36 quarry blast events remain
#
#  >>processing radius 0.049
#     ~~~the selection radius 0.049 found 58 matches and 4 non-unique assigments.
#     ~~~out of 36 initial events, 33 quarry blast events remain
#
#  >>processing radius 0.05
#     ~~~the selection radius 0.05 found 56 matches and 4 non-unique assigments.
#     ~~~out of 33 initial events, 32 quarry blast events remain
#
#  >>processing radius 0.051000000000000004
#     ~~~the selection radius 0.051000000000000004 found 56 matches and 4 non-unique assigments.
#     ~~~out of 32 initial events, 31 quarry blast events remain
#
#  >>processing radius 0.052000000000000005
#     ~~~the selection radius 0.052000000000000005 found 57 matches and 4 non-unique assigments.
#     ~~~out of 31 initial events, 29 quarry blast events remain
#
#  >>processing radius 0.053000000000000005
#     ~~~the selection radius 0.053000000000000005 found 56 matches and 4 non-unique assigments.
#     ~~~out of 29 initial events, 28 quarry blast events remain
#
#  >>processing radius 0.054
#     ~~~the selection radius 0.054 found 57 matches and 4 non-unique assigments.
#     ~~~out of 28 initial events, 27 quarry blast events remain
#
#  >>processing radius 0.055
#     ~~~the selection radius 0.055 found 59 matches and 4 non-unique assigments.
#     ~~~out of 27 initial events, 26 quarry blast events remain
#
#  >>processing radius 0.056
#     ~~~the selection radius 0.056 found 58 matches and 4 non-unique assigments.
#     ~~~out of 26 initial events, 26 quarry blast events remain
#
#  >>processing radius 0.057
#     ~~~the selection radius 0.057 found 58 matches and 4 non-unique assigments.
#     ~~~out of 26 initial events, 26 quarry blast events remain
#
#  >>processing radius 0.058
#     ~~~the selection radius 0.058 found 61 matches and 4 non-unique assigments.
#     ~~~out of 26 initial events, 25 quarry blast events remain
#
#  >>processing radius 0.059000000000000004
#     ~~~the selection radius 0.059000000000000004 found 60 matches and 4 non-unique assigments.
#     ~~~out of 25 initial events, 25 quarry blast events remain
#
#  >>processing radius 0.060000000000000005
#     ~~~the selection radius 0.060000000000000005 found 60 matches and 4 non-unique assigments.
#     ~~~out of 25 initial events, 25 quarry blast events remain
#
#  >>processing radius 0.061000000000000006
#     ~~~the selection radius 0.061000000000000006 found 61 matches and 4 non-unique assigments.
#     ~~~out of 25 initial events, 24 quarry blast events remain
#
#  >>processing radius 0.062000000000000006
#     ~~~the selection radius 0.062000000000000006 found 60 matches and 4 non-unique assigments.
#     ~~~out of 24 initial events, 24 quarry blast events remain
#
#  >>processing radius 0.063
#     ~~~the selection radius 0.063 found 60 matches and 4 non-unique assigments.
#     ~~~out of 24 initial events, 24 quarry blast events remain
#
#  >>processing radius 0.064
#     ~~~the selection radius 0.064 found 63 matches and 4 non-unique assigments.
#     ~~~out of 24 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.065
#     ~~~the selection radius 0.065 found 63 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.066
#     ~~~the selection radius 0.066 found 63 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.067
#     ~~~the selection radius 0.067 found 63 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.068
#     ~~~the selection radius 0.068 found 63 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.069
#     ~~~the selection radius 0.069 found 63 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.06999999999999999
#     ~~~the selection radius 0.06999999999999999 found 63 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.071
#     ~~~the selection radius 0.071 found 63 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.072
#     ~~~the selection radius 0.072 found 63 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.073
#     ~~~the selection radius 0.073 found 63 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.074
#     ~~~the selection radius 0.074 found 64 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.075
#     ~~~the selection radius 0.075 found 65 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.076
#     ~~~the selection radius 0.076 found 66 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.077
#     ~~~the selection radius 0.077 found 68 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.078
#     ~~~the selection radius 0.078 found 69 matches and 4 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.079
#     ~~~the selection radius 0.079 found 72 matches and 5 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#
#  >>processing radius 0.08
#     ~~~the selection radius 0.08 found 72 matches and 5 non-unique assigments.
#     ~~~out of 23 initial events, 23 quarry blast events remain
#  >>number of doubles': 23

# %%
#remain_blasts_catalogue
seisblast_files = '/home/bmelo/bin/SeisBlast/files'
remain_blasts_catalogue.to_csv(f'{seisblast_files}/Eire_blasts_remain.csv', index=False)

# %% [markdown]
# **Plot results with PyGMT**

# %%
# fig = pygmt.Figure()
# with fig.subplot(nrows=1, ncols=2, figsize=("30c", "10c"), autolabel="True"): #frame=["WSrt"],  margins="0.5c"): #sharex="b", sharey="l",

#     # First panel
#     with fig.set_panel(panel=0):
#         fig.basemap(region=region, projection="M10c", frame=["a0.5", "WSrt"])
#         fig.coast(shorelines=True, water="skyblue", land="lightgray")
#         #Plot quarry mine locations as black circles
#         fig.plot(
#             x=quarries["lon"],
#             y=quarries["lat"],
#             style="s0.3c",
#             fill="black",
#             pen="black",
#             label="Quarry"
#         )
#         # Plot initial blast location
#         fig.plot(x=quarries_james["lon"],
#                 y=quarries_james["lat"],
#                 style="t0.2c",
#                 fill="green",
#                 pen="black",
#                 label="Relocated Blasts")
        
#         fig.legend(position="jTL")

#     # Second panel
#     with fig.set_panel(panel=1):
#         fig.basemap(region=region, projection="M10c", frame=["a0.5", "WSrt"])
#         fig.coast(shorelines=True, water="skyblue", land="lightgray")
#         # # Plot quarry mine locations as black circles
#         fig.plot(
#             x=quarries["lon"],
#             y=quarries["lat"],
#             style="s0.3c",
#             fill="black",
#             pen="black",
#             label="Quarry"
#         )
#         # Plot relocated blasts as red circles
#         fig.plot(x=relocated_blasts_all["lon-quarry"],
#                 y=relocated_blasts_all["lat-quarry"],
#                 style="t0.2c",
#                 fill="green",
#                 pen="black",
#                 label="Relocated Blasts")
#         # Plot remaining blasts as yellow circles
#         fig.plot(
#             x=remain_blasts_catalogue['LON(deg)'],
#             y=remain_blasts_catalogue['LAT(deg)'],
#             style="t0.2c",
#             fill="yellow",
#             pen="black",
#             label="Lost Blasts"
#         )
#         # Plot remaining blasts as yellow circles
#         fig.plot(
#             x=doubles_all['lon_ev'],
#             y=doubles_all['lat_ev'],
#             style="t0.2c",
#             fill="red",
#             pen="black",
#             label="Review Blasts"
#         )
    
#     #fig.legend(position="jTL")

# #fig.subplot(end=True)
# fig.show()
# Out:
# pygmt-session [ERROR]: Failure while decoding subplot information file /home/bmelo/.gmt/sessions/gmt_session.2348388/gmt.subplot.29.  Bad format? [0	0	0	1	2	0.0000	0.0000	5.7367	3.9370	e] (n=5)
# pygmt-session [ERROR]: Failure while decoding subplot information file /home/bmelo/.gmt/sessions/gmt_session.2348388/gmt.subplot.29.  Bad format? [0	0	0	1	2	0.0000	0.0000	5.7367	3.9370	e] (n=5)
# pygmt-session [ERROR]: Failure while decoding subplot information file /home/bmelo/.gmt/sessions/gmt_session.2348388/gmt.subplot.29.  Bad format? [1	0	1	1	2	6.0743	0.0000	5.7367	3.9370	f] (n=5)
# pygmt-session [ERROR]: Failure while decoding subplot information file /home/bmelo/.gmt/sessions/gmt_session.2348388/gmt.subplot.29.  Bad format? [1	0	1	1	2	6.0743	0.0000	5.7367	3.9370	f] (n=5)
# subplot [ERROR]: Failure while decoding subplot information file /home/bmelo/.gmt/sessions/gmt_session.2348388/gmt.subplot.29.  Bad format? [1	0	1	1	2	6.0743	0.0000	5.7367	3.9370	f] (n=5)
# subplot [ERROR]: No subplot information file!
# ---------------------------------------------------------------------------
# GMTCLibError                              Traceback (most recent call last)
# Cell In[43], line 2
#       1 fig = pygmt.Figure()
# ----> 2 with fig.subplot(nrows=1, ncols=2, figsize=("30c", "10c"), autolabel="True"): #frame=["WSrt"],  margins="0.5c"): #sharex="b", sharey="l",
#       3
#       4     # First panel
#       5     with fig.set_panel(panel=0):
#       6         fig.basemap(region=region, projection="M10c", frame=["a0.5", "WSrt"])
#
# File ~/miniconda3/envs/seisblast/lib/python3.12/contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File ~/miniconda3/envs/seisblast/lib/python3.12/site-packages/pygmt/src/subplot.py:170, in subplot(self, nrows, ncols, **kwargs)
#     168 finally:
#     169     with Session() as lib:
# --> 170         lib.call_module(
#     171             module="subplot", args=["end", *build_arg_list({"V": kwargs.get("V")})]
#     172         )
#
# File ~/miniconda3/envs/seisblast/lib/python3.12/site-packages/pygmt/clib/session.py:660, in Session.call_module(self, module, args)
#     658 if status != 0:
#     659     msg = f"Module '{module}' failed with status code {status}:\n{self._error_message}"
# --> 660     raise GMTCLibError(msg)
#
# GMTCLibError: Module 'subplot' failed with status code 15:
# subplot [ERROR]: Failure while decoding subplot information file /home/bmelo/.gmt/sessions/gmt_session.2348388/gmt.subplot.29.  Bad format? [1	0	1	1	2	6.0743	0.0000	5.7367	3.9370	f] (n=5)
# subplot [ERROR]: No subplot information file!
