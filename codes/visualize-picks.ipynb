# %%
import pandas as pd
import SeisBlast as sb
import matplotlib.pyplot as plt
#import wavelet as wvl
seisblast_files = '/home/bmelo/bin/SeisBlast/files'

# %%
#read blast data
quarry_catalogue = pd.read_csv(f'{seisblast_files}/JSmutual_catalogue.csv') #catalogue in common between J and S
s_bul_dir = "/mnt/store/senad/repos/for_bruna/SEISCOMP_EVENTS/BULLETINS/"
j_bul_dir = "/mnt/REPO/QUARRY-BLASTS/BULLETINS/"
quarry_catalogue[:20]
# Out:
#     Unnamed: 0      EVENT-ID        DATE          TIME  LAT(deg)  LAT-ERR(km)  \
# 0           83  dias2013ounh  2013-07-30  10:56:29.388  54.11401        0.847
# 1          102  dias2013psgr  2013-08-12  10:51:10.146  54.82306        2.148
# 2          124  dias2013qvsa  2013-08-28  13:32:30.950  52.89928        1.061
# 3          130  dias2013qxms  2013-08-29  13:07:57.382  53.37685        1.126
# 4          137  dias2013rlzk  2013-09-06  11:26:58.830  54.58620        1.844
# 5          139  dias2013rmcr  2013-09-06  13:05:35.433  53.79102        0.771
# 6          140  dias2013rmct  2013-09-06  13:07:39.723  53.79372        1.010
# 7          141  dias2013rrkw  2013-09-09  10:54:07.313  54.88547        2.780
# 8          142  dias2013rrls  2013-09-09  11:19:54.672  53.73794        0.808
# 9          144  dias2013rrny  2013-09-09  12:28:12.343  54.61351        2.327
# 10         145  dias2013rrpj  2013-09-09  13:11:02.092  52.35267        1.055
# 11         146  dias2013rrqx  2013-09-09  13:57:19.605  54.17544        0.880
# 12         149  dias2013rtkg  2013-09-10  12:52:05.358  55.10579        1.258
# 13         150  dias2013rtkq  2013-09-10  13:04:21.802  51.82265        1.382
# 14         151  dias2013rtld  2013-09-10  13:19:38.321  54.51592        0.991
# 15         152  dias2013rtnn  2013-09-10  14:31:58.410  52.54602        1.091
# 16         153  dias2013rvam  2013-09-11  10:12:31.349  54.81395        1.980
# 17         154  dias2013rvbq  2013-09-11  10:47:40.111  52.57035        1.112
# 18         155  dias2013rvco  2013-09-11  11:14:59.580  54.02964        0.941
# 19         156  dias2013rvfe  2013-09-11  12:34:22.833  55.06705        1.675
#
#     LON(deg)  LON-ERR(km)  DEPTH(km)  RMS(s)  AZ-GAP(deg)  N_PHASES  MAG(ML)
# 0   -8.17115        1.370        0.0   0.451         77.3        36     1.18
# 1   -6.06838        1.228        0.0   0.612        105.1        25     1.24
# 2   -9.06385        1.245        0.0   0.316         93.1        35     1.30
# 3   -9.19604        1.019        0.0   0.481         86.4        42     1.17
# 4   -5.78568        1.187        0.0   0.864         83.3        23     1.08
# 5   -7.72047        0.958        0.0   0.636         48.9        56     1.38
# 6   -7.70450        1.232        0.0   0.494         90.0        35     1.23
# 7   -6.28009        1.447        0.0   0.396        148.2        21     0.91
# 8   -7.11559        1.101        0.0   0.397         61.4        55     1.28
# 9   -5.73176        1.554        0.0   0.517        103.0        16     1.18
# 10  -9.77242        2.083        0.0   0.419        140.6        24     1.23
# 11  -7.62014        1.206        0.0   0.314         49.5        44     1.50
# 12  -7.43027        1.412        0.0   0.446        110.0        34     0.95
# 13  -8.46390        1.262        0.0   0.726        125.9        33     1.54
# 14  -7.65635        1.550        0.0   0.407         99.8        36     0.88
# 15  -7.83602        1.031        0.0   0.404         67.5        39     1.47
# 16  -5.90898        1.210        0.0   0.469         94.2        29     1.32
# 17  -9.05711        1.219        0.0   0.511         96.9        36     1.48
# 18  -6.84655        1.336        0.0   0.439         74.7        46     1.27
# 19  -7.81982        1.133        0.0   0.395        128.2        42     0.68

# %%
evind = 2
ev_id = quarry_catalogue['EVENT-ID'].iloc[evind]
df,info = sb.list_picks(quarry_catalogue,j_bul_dir,ev_id)
df
# Out:
#          sta net     dist      distkm                    time  \
# phase                                                       P
# 0      IA004  IA  0.29167   32.432224 2013-08-28 13:32:35.953
# 1      IA006  IA  0.50792   56.478127 2013-08-28 13:32:40.319
# 2      IA007  IA  1.23232  137.027732 2013-08-28 13:32:53.766
# 3      IA009  IA  0.96918  107.767899 2013-08-28 13:32:49.295
# 4      IA010  IA  1.43649  159.730400 2013-08-28 13:32:57.107
# 5      IA013  IA  1.14655  127.490543 2013-08-28 13:32:52.286
# 6      IAD18  IA  0.87523   97.321136 2013-08-28 13:32:47.455
# 7      IAD23  IA  0.74086   82.379873 2013-08-28 13:32:45.668
# 8      IAD38  IA  1.21061  134.613690 2013-08-28 13:32:53.576
# 9      IAP07  IA  1.41820  157.696645 2013-08-28 13:32:56.748
# 10      IGLA  EI  0.55385   61.585310 2013-08-28 13:32:41.672
# 11     UCAR1  EI  0.62014   68.956422 2013-08-28 13:32:42.803
# 12     UCAR2  EI  0.66752   74.224837 2013-08-28 13:32:43.501
# 13     UCAR3  EI  0.65230   72.532451 2013-08-28 13:32:43.438
# 14      UD02  EI  2.03199  225.946979 2013-08-28 13:33:06.664
# 15     UGAL1  EI  1.32570  147.411114 2013-08-28 13:32:55.342
# 16     UMOLE  EI  1.67361  186.096941 2013-08-28 13:33:00.934
# 17       VAL  EI  1.20292  133.758601 2013-08-28 13:32:53.502
#
#
# phase                       S
# 0     2013-08-28 13:32:39.667
# 1     2013-08-28 13:32:47.058
# 2     2013-08-28 13:33:10.660
# 3     2013-08-28 13:33:02.345
# 4     2013-08-28 13:33:16.413
# 5     2013-08-28 13:33:07.972
# 6     2013-08-28 13:32:58.859
# 7     2013-08-28 13:32:55.163
# 8     2013-08-28 13:33:10.030
# 9     2013-08-28 13:33:15.699
# 10    2013-08-28 13:32:48.360
# 11    2013-08-28 13:32:51.678
# 12    2013-08-28 13:32:52.308
# 13    2013-08-28 13:32:52.098
# 14    2013-08-28 13:33:32.707
# 15    2013-08-28 13:33:12.717
# 16    2013-08-28 13:33:23.636
# 17                        NaT

# %%
sb.eventmap(quarry_catalogue,df,evind)

# %%
sb.diff_picks(quarry_catalogue,ev_id,s_bul_dir,j_bul_dir)
# Out:
# -- reading event id: dias2013qvsa --
#
#     > bulletin_1 has 20 P times; bulletin_2 has 18
#     > No common station and phase picks found between the two bulletins
# /mnt/home_geo/bmelo/bin/SeisBlast/SeisBlast/SeisBlast/compare_picktimes.py:95: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   merge_picks = pd.merge(bul1_picks.sort_index(), bul2_picks.sort_index(), on=['sta','net'], how='inner', suffixes=['1','2'])
# (None, 20, 18, 0, 17)

# %%
sb.seisdis(df,info,0,40,5,40,0.1)

# %%
sb.plot_wave(df,info,0,50,2,5,2)

# %%
ind = 2
wf,trace = sb.plot_freq(df,info,10,50,2,5,1,40,ind,filterall='No',cfs=1,cfw=4)

# %%
from obspy.taup import TauPyModel
model = TauPyModel(model="ak135irelandcrust")
arrivals = model.get_travel_times(source_depth_in_km=0,distance_in_degree=df.dist[ind])
print(arrivals)
# Out:
# 16 arrivals
# 	P phase arrival at 5.489 seconds
# 	PP phase arrival at 5.495 seconds
# 	S phase arrival at 9.553 seconds
# 	SS phase arrival at 9.563 seconds
# 	PcP phase arrival at 509.480 seconds
# 	PcS phase arrival at 721.260 seconds
# 	ScP phase arrival at 721.260 seconds
# 	ScS phase arrival at 933.041 seconds
# 	PKiKP phase arrival at 992.585 seconds
# 	SKiKP phase arrival at 1204.364 seconds
# 	PKIKKIKP phase arrival at 1911.096 seconds
# 	PKIKKIKS phase arrival at 2122.875 seconds
# 	SKIKKIKP phase arrival at 2122.875 seconds
# 	SKIKKIKS phase arrival at 2334.654 seconds
# 	PKIKPPKIKP phase arrival at 2420.572 seconds
# 	SKIKSSKIKS phase arrival at 3267.688 seconds

# %%
evdf=df.iloc[[ind]]
sb.plot_psa(info,evdf,5,20,5,30)

# %%
#quarry_catalogue['QF'] = None
quarry_catalogue.loc[evind,'QF'] = '2'
quarry_catalogue.to_csv('ev_randomsample_qf.csv',index=False)
quarry_catalogue[10:20]
# Out:
#     Unnamed: 0      EVENT-ID        DATE          TIME  LAT(deg)  LAT-ERR(km)  \
# 10         145  dias2013rrpj  2013-09-09  13:11:02.092  52.35267        1.055
# 11         146  dias2013rrqx  2013-09-09  13:57:19.605  54.17544        0.880
# 12         149  dias2013rtkg  2013-09-10  12:52:05.358  55.10579        1.258
# 13         150  dias2013rtkq  2013-09-10  13:04:21.802  51.82265        1.382
# 14         151  dias2013rtld  2013-09-10  13:19:38.321  54.51592        0.991
# 15         152  dias2013rtnn  2013-09-10  14:31:58.410  52.54602        1.091
# 16         153  dias2013rvam  2013-09-11  10:12:31.349  54.81395        1.980
# 17         154  dias2013rvbq  2013-09-11  10:47:40.111  52.57035        1.112
# 18         155  dias2013rvco  2013-09-11  11:14:59.580  54.02964        0.941
# 19         156  dias2013rvfe  2013-09-11  12:34:22.833  55.06705        1.675
#
#     LON(deg)  LON-ERR(km)  DEPTH(km)  RMS(s)  AZ-GAP(deg)  N_PHASES  MAG(ML)  \
# 10  -9.77242        2.083        0.0   0.419        140.6        24     1.23
# 11  -7.62014        1.206        0.0   0.314         49.5        44     1.50
# 12  -7.43027        1.412        0.0   0.446        110.0        34     0.95
# 13  -8.46390        1.262        0.0   0.726        125.9        33     1.54
# 14  -7.65635        1.550        0.0   0.407         99.8        36     0.88
# 15  -7.83602        1.031        0.0   0.404         67.5        39     1.47
# 16  -5.90898        1.210        0.0   0.469         94.2        29     1.32
# 17  -9.05711        1.219        0.0   0.511         96.9        36     1.48
# 18  -6.84655        1.336        0.0   0.439         74.7        46     1.27
# 19  -7.81982        1.133        0.0   0.395        128.2        42     0.68
#
#      QF
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN

# %%
# from obspy.taup import plot_travel_times
# from obspy.taup import TauPyModel
# import matplotlib.pyplot as plt
# model = TauPyModel(model="ak135irelandcrust")

# fig, ax = plt.subplots(figsize=(9, 9))
# ax.set_ylim(0,2)
# ax = plot_travel_times(source_depth=0,ax=ax, fig=fig, max_degrees=3, model=model) #, phase_list=["P","S","PP"]

# %%
# from obspy.geodetics import degrees2kilometers
# # Define source depth and maximum epicentral distance
# source_depth = 0
# max_distance = 3  # in degrees

# # Get travel times for specific phases
# phases = ["P", "S", "PP"]
# distances = []
# times = {phase: [] for phase in phases}

# for distance in range(0, int(max_distance * 10) + 1):  # finer steps for smooth plots
#     dist_in_deg = distance / 10.0  # Convert steps to degrees
#     arrivals = model.get_ray_paths(
#         source_depth_in_km=source_depth, 
#         distance_in_degree=dist_in_deg, 
#         phase_list=phases
#     )
#     dist_in_km = degrees2kilometers(dist_in_deg)
#     distances.append(dist_in_km)
#     for phase in phases:
#         phase_arrival = [a.time for a in arrivals if a.name == phase]
#         if phase_arrival:
#             times[phase].append(phase_arrival[0])
#         else:
#             times[phase].append(None)  # No arrival for this phase at this distance

# # Plot manually
# fig, ax = plt.subplots(figsize=(9, 9))
# for phase, time_list in times.items():
#     ax.plot(
#         distances, 
#         time_list, 
#         label=phase, 
#         marker='o', 
#         linestyle='-', 
#         markersize=4
#     )

# # Customise the plot
# ax.set_xlim(0, degrees2kilometers(max_distance))
# ax.set_ylim(0, max([max(t) for t in times.values() if t]))
# ax.set_xlabel("Epicentral Distance (km)")
# ax.set_ylabel("Travel Time (seconds)")
# ax.legend()
# ax.grid(True)
# plt.show()
