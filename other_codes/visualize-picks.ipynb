# %%
import pandas as pd
import SeisBlast as sb
import matplotlib.pyplot as plt
#import wavelet as wvl
seisblast_files = '/home/bmelo/bin/SeisBlast/files'

# %%
#read blast data
quarry_catalogue = pd.read_csv(f'{seisblast_files}/JSmutual_catalogue.csv') #catalogue in common between J and S
s_bul_dir = "/mnt/store/senad/repos/for_bruna/SEISCOMP_EVENTS/BULLETINS/"
j_bul_dir = "/mnt/REPO/QUARRY-BLASTS/BULLETINS/"
quarry_catalogue[60:80]
# Out:
#     Unnamed: 0      EVENT-ID        DATE          TIME  LAT(deg)  LAT-ERR(km)  \
# 60         215  dias2013tdww  2013-09-30  12:08:05.881  54.19036        1.141
# 61         216  dias2013tdze  2013-09-30  13:18:40.716  53.49338        1.665
# 62         217  dias2013tdzj  2013-09-30  13:24:36.513  53.90533        1.014
# 63         218  dias2013teax  2013-09-30  14:10:46.268  52.50473        1.317
# 64         219  dias2013tftd  2013-10-01  12:31:44.318  53.83391        0.799
# 65         220  dias2013thpv  2013-10-02  13:07:56.512  54.24371        1.242
# 66         221  dias2013tjfx  2013-10-03  10:23:50.315  53.09470        1.270
# 67         222  dias2013tjie  2013-10-03  11:31:44.358  53.19685        1.723
# 68         224  dias2013tjla  2013-10-03  12:57:57.681  53.42705        1.204
# 69         226  dias2013tjmg  2013-10-03  13:35:12.483  52.76719        1.381
# 70         228  dias2013tlfz  2013-10-04  12:41:43.271  55.05133        2.227
# 71         229  dias2013tlgm  2013-10-04  12:57:36.837  54.32099        1.780
# 72         230  dias2013tlkg  2013-10-04  14:51:42.459  54.23159        1.035
# 73         231  dias2013tnab  2013-10-05  11:59:09.118  54.32023        0.899
# 74         232  dias2013tqpq  2013-10-07  11:15:55.968  52.54540        1.650
# 75         233  dias2013tqqz  2013-10-07  11:55:57.790  52.63535        2.254
# 76         234  dias2013tqtz  2013-10-07  13:27:14.521  53.36284        2.247
# 77         235  dias2013tqun  2013-10-07  13:43:51.309  51.88661        2.489
# 78         236  dias2013tqwf  2013-10-07  14:34:25.013  55.07967        2.539
# 79         237  dias2013tsln  2013-10-08  11:27:17.433  54.14305        0.966
#
#     LON(deg)  LON-ERR(km)  DEPTH(km)  RMS(s)  AZ-GAP(deg)  N_PHASES  MAG(ML)
# 60  -6.19058        1.533        0.0   0.421         93.7        30     1.07
# 61  -6.83834        1.612        0.0   0.578        150.3        17     0.93
# 62  -7.64919        1.325        0.0   0.482         82.2        30     1.07
# 63  -8.80718        1.239        0.0   0.574         83.7        26     1.10
# 64  -8.12776        1.029        0.0   0.539         62.4        51     1.47
# 65  -8.49118        2.182        0.0   0.454        128.4        24     1.08
# 66  -8.80608        1.036        0.0   0.523         96.9        33     1.15
# 67  -8.51638        1.311        0.0   0.411         85.6        16     0.86
# 68  -8.94784        1.100        0.0   0.400         93.6        29     1.19
# 69  -6.92826        1.213        0.0   0.492         67.9        26     1.09
# 70  -6.77787        1.407        0.0   0.345        160.0        26     1.20
# 71  -5.85324        1.596        0.0   0.513        103.8        20     1.01
# 72  -6.92226        1.377        0.0   0.602         68.5        32     1.21
# 73  -8.21243        1.411        0.0   0.570         72.3        36     1.30
# 74  -7.71557        1.233        0.0   0.316        118.8        25     1.15
# 75  -6.28756        2.972        0.0   0.323        220.6        16     1.02
# 76  -9.21204        1.452        0.0   0.582        125.2        15     1.17
# 77  -8.15586        3.012        0.0   0.333        153.9        11     1.12
# 78  -7.83253        1.493        0.0   0.433        155.6        26     0.92
# 79  -7.61566        1.351        0.0   0.613         60.8        33     1.03

# %%
evind = 64
ev_id = quarry_catalogue['EVENT-ID'].iloc[evind]
df,info = sb.list_picks(quarry_catalogue,j_bul_dir,ev_id)
df
# Out:
#          sta net     dist      distkm                    time  \
# phase                                                       P
# 0       CLGH  GB  1.71848  191.086258 2013-10-01 12:32:14.034
# 1       DL21  SM  1.27724  142.022608 2013-10-01 12:32:08.015
# 2       DL22  SM  1.34836  149.930791 2013-10-01 12:32:09.485
# 3       DL23  SM  1.37227  152.589462 2013-10-01 12:32:09.833
# 4      IA002  IA  0.56891   63.259906 2013-10-01 12:31:56.169
# 5      IA003  IA  0.75148   83.560763 2013-10-01 12:31:58.566
# 6      IA004  IA  0.80639   89.666477 2013-10-01 12:32:00.668
# 7      IA006  IA  1.34904  150.006404 2013-10-01 12:32:08.570
# 8      IA007  IA  1.71891  191.134071                     NaT
# 9      IA009  IA  0.49880   55.464029 2013-10-01 12:31:54.161
# 10     IA010  IA  0.66028   73.419786 2013-10-01 12:31:56.939
# 11     IA012  IA  1.41247  157.059498 2013-10-01 12:32:10.355
# 12     IA013  IA  0.91558  101.807851 2013-10-01 12:32:01.879
# 13     IAD18  IA  0.22068   24.538496 2013-10-01 12:31:48.232
# 14     IAD23  IA  1.11996  124.533870 2013-10-01 12:32:05.313
# 15     IAD33  IA  0.63106   70.170670                     NaT
# 16      IDGL  EI  1.29309  143.785048 2013-10-01 12:32:09.311
# 17      IGLA  EI  0.85104   94.631330 2013-10-01 12:32:00.014
# 18      IWEX  EI  1.67448  186.193681 2013-10-01 12:32:15.285
# 19     UCAR1  EI  1.14160  126.940128 2013-10-01 12:32:06.190
# 20     UCAR2  EI  1.14652  127.487207 2013-10-01 12:32:05.807
# 21     UCAR3  EI  1.17032  130.133647 2013-10-01 12:32:06.104
# 22     UCREE  EI  1.26728  140.915107 2013-10-01 12:32:07.686
# 23      UD01  EI  1.03266  114.826553 2013-10-01 12:32:03.930
# 24      UD03  EI  1.06815  118.772861 2013-10-01 12:32:04.670
# 25      UD04  EI  1.08527  120.676518 2013-10-01 12:32:04.955
# 26     UHELL  EI  1.23090  136.869835 2013-10-01 12:32:07.520
# 27     USUGA  EI  1.34863  149.960814 2013-10-01 12:32:08.946
#
#
# phase                       S
# 0     2013-10-01 12:32:35.645
# 1                         NaT
# 2     2013-10-01 12:32:27.118
# 3     2013-10-01 12:32:27.815
# 4     2013-10-01 12:32:02.466
# 5     2013-10-01 12:32:08.150
# 6     2013-10-01 12:32:10.181
# 7     2013-10-01 12:32:26.828
# 8     2013-10-01 12:32:37.792
# 9     2013-10-01 12:32:00.536
# 10    2013-10-01 12:32:05.656
# 11    2013-10-01 12:32:29.033
# 12    2013-10-01 12:32:14.473
# 13    2013-10-01 12:31:51.546
# 14    2013-10-01 12:32:19.230
# 15    2013-10-01 12:32:05.366
# 16    2013-10-01 12:32:26.016
# 17    2013-10-01 12:32:11.341
# 18    2013-10-01 12:32:36.806
# 19    2013-10-01 12:32:21.144
# 20    2013-10-01 12:32:21.202
# 21    2013-10-01 12:32:21.608
# 22                        NaT
# 23    2013-10-01 12:32:17.315
# 24    2013-10-01 12:32:18.185
# 25    2013-10-01 12:32:19.056
# 26                        NaT
# 27    2013-10-01 12:32:27.292

# %%
sb.eventmap(quarry_catalogue,df,evind)

# %%
sb.diff_picks(quarry_catalogue,ev_id,s_bul_dir,j_bul_dir)
# Out:
# -- reading event id: dias2013tftd --
#
#     > bulletin_1 has 25 P times; bulletin_2 has 28
#     > out of 22 common station and phase picks. 3 pick times are different
# /mnt/home_geo/bmelo/bin/SeisBlast/SeisBlast/SeisBlast/compare_picktimes.py:95: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   merge_picks = pd.merge(bul1_picks.sort_index(), bul2_picks.sort_index(), on=['sta','net'], how='inner', suffixes=['1','2'])
# (         sta net    dist1     distkm1                   time1        dist2  \
#  phase                                                       P   S
#  4      IA004  IA  0.79634   88.548968 2013-10-01 12:32:00.286 NaT  0.80639
#  12      IDGL  EI  1.30204  144.780242 2013-10-01 12:32:08.595 NaT  1.29309
#  18      UD03  EI  1.07529  119.566793 2013-10-01 12:32:04.408 NaT  1.06815
#
#            distkm2                   time2                          \
#  phase                                   P                       S
#  4       89.666477 2013-10-01 12:32:00.668 2013-10-01 12:32:10.181
#  12     143.785048 2013-10-01 12:32:09.311 2013-10-01 12:32:26.016
#  18     118.772861 2013-10-01 12:32:04.670 2013-10-01 12:32:18.185
#
#        Ptime1_seconds Ptime2_seconds Ptime_diff_seconds
#  phase
#  4             15.968         16.350              0.382
#  12            24.277         24.993              0.716
#  18            20.090         20.352              0.262  ,
#  25,
#  26,
#  5,
#  25)

# %%
sb.seisdis(df,info,0,30,2,20,0.1)

# %%
sb.plot_wave(df,info,0,50,2,10,13)

# %%
ind = 2
wf,trace = sb.plot_freq(df,info,10,50,2,5,1,40,ind,filterall='No',cfs=1,cfw=4)

# %%
from obspy.taup import TauPyModel
model = TauPyModel(model="ak135irelandcrust")
arrivals = model.get_travel_times(source_depth_in_km=0,distance_in_degree=df.dist[ind])
print(arrivals)
# Out:
# 24 arrivals
# 	P phase arrival at 19.763 seconds
# 	P phase arrival at 20.019 seconds
# 	P phase arrival at 20.027 seconds
# 	P phase arrival at 20.037 seconds
# 	P phase arrival at 20.044 seconds
# 	PP phase arrival at 20.320 seconds
# 	S phase arrival at 34.411 seconds
# 	S phase arrival at 34.835 seconds
# 	S phase arrival at 34.855 seconds
# 	S phase arrival at 34.871 seconds
# 	S phase arrival at 34.876 seconds
# 	SS phase arrival at 35.365 seconds
# 	PcP phase arrival at 509.532 seconds
# 	PcS phase arrival at 721.328 seconds
# 	ScP phase arrival at 721.328 seconds
# 	ScS phase arrival at 933.138 seconds
# 	PKiKP phase arrival at 992.598 seconds
# 	SKiKP phase arrival at 1204.377 seconds
# 	PKIKKIKP phase arrival at 1911.084 seconds
# 	PKIKKIKS phase arrival at 2122.864 seconds
# 	SKIKKIKP phase arrival at 2122.864 seconds
# 	SKIKKIKS phase arrival at 2334.643 seconds
# 	PKIKPPKIKP phase arrival at 2420.556 seconds
# 	SKIKSSKIKS phase arrival at 3267.675 seconds

# %%
evdf=df.iloc[[ind]]
sb.plot_psa(info,evdf,5,20,5,30)

# %%
#quarry_catalogue['QF'] = None
quarry_catalogue.loc[evind,'QF'] = '2'
quarry_catalogue.to_csv('ev_randomsample_qf.csv',index=False)
quarry_catalogue[10:20]
# Out:
#     Unnamed: 0      EVENT-ID        DATE          TIME  LAT(deg)  LAT-ERR(km)  \
# 10         145  dias2013rrpj  2013-09-09  13:11:02.092  52.35267        1.055
# 11         146  dias2013rrqx  2013-09-09  13:57:19.605  54.17544        0.880
# 12         149  dias2013rtkg  2013-09-10  12:52:05.358  55.10579        1.258
# 13         150  dias2013rtkq  2013-09-10  13:04:21.802  51.82265        1.382
# 14         151  dias2013rtld  2013-09-10  13:19:38.321  54.51592        0.991
# 15         152  dias2013rtnn  2013-09-10  14:31:58.410  52.54602        1.091
# 16         153  dias2013rvam  2013-09-11  10:12:31.349  54.81395        1.980
# 17         154  dias2013rvbq  2013-09-11  10:47:40.111  52.57035        1.112
# 18         155  dias2013rvco  2013-09-11  11:14:59.580  54.02964        0.941
# 19         156  dias2013rvfe  2013-09-11  12:34:22.833  55.06705        1.675
#
#     LON(deg)  LON-ERR(km)  DEPTH(km)  RMS(s)  AZ-GAP(deg)  N_PHASES  MAG(ML)  \
# 10  -9.77242        2.083        0.0   0.419        140.6        24     1.23
# 11  -7.62014        1.206        0.0   0.314         49.5        44     1.50
# 12  -7.43027        1.412        0.0   0.446        110.0        34     0.95
# 13  -8.46390        1.262        0.0   0.726        125.9        33     1.54
# 14  -7.65635        1.550        0.0   0.407         99.8        36     0.88
# 15  -7.83602        1.031        0.0   0.404         67.5        39     1.47
# 16  -5.90898        1.210        0.0   0.469         94.2        29     1.32
# 17  -9.05711        1.219        0.0   0.511         96.9        36     1.48
# 18  -6.84655        1.336        0.0   0.439         74.7        46     1.27
# 19  -7.81982        1.133        0.0   0.395        128.2        42     0.68
#
#      QF
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN

# %%
# from obspy.taup import plot_travel_times
# from obspy.taup import TauPyModel
# import matplotlib.pyplot as plt
# model = TauPyModel(model="ak135irelandcrust")

# fig, ax = plt.subplots(figsize=(9, 9))
# ax.set_ylim(0,2)
# ax = plot_travel_times(source_depth=0,ax=ax, fig=fig, max_degrees=3, model=model) #, phase_list=["P","S","PP"]

# %%
# from obspy.geodetics import degrees2kilometers
# # Define source depth and maximum epicentral distance
# source_depth = 0
# max_distance = 3  # in degrees

# # Get travel times for specific phases
# phases = ["P", "S", "PP"]
# distances = []
# times = {phase: [] for phase in phases}

# for distance in range(0, int(max_distance * 10) + 1):  # finer steps for smooth plots
#     dist_in_deg = distance / 10.0  # Convert steps to degrees
#     arrivals = model.get_ray_paths(
#         source_depth_in_km=source_depth, 
#         distance_in_degree=dist_in_deg, 
#         phase_list=phases
#     )
#     dist_in_km = degrees2kilometers(dist_in_deg)
#     distances.append(dist_in_km)
#     for phase in phases:
#         phase_arrival = [a.time for a in arrivals if a.name == phase]
#         if phase_arrival:
#             times[phase].append(phase_arrival[0])
#         else:
#             times[phase].append(None)  # No arrival for this phase at this distance

# # Plot manually
# fig, ax = plt.subplots(figsize=(9, 9))
# for phase, time_list in times.items():
#     ax.plot(
#         distances, 
#         time_list, 
#         label=phase, 
#         marker='o', 
#         linestyle='-', 
#         markersize=4
#     )

# # Customise the plot
# ax.set_xlim(0, degrees2kilometers(max_distance))
# ax.set_ylim(0, max([max(t) for t in times.values() if t]))
# ax.set_xlabel("Epicentral Distance (km)")
# ax.set_ylabel("Travel Time (seconds)")
# ax.legend()
# ax.grid(True)
# plt.show()
